# %%
! pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VN28ceooZnimGyMKzkNo")
project = rf.workspace("agts").project("hairnet")
version = project.version(15)
dataset = version.download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to hairnet-15 in yolov5pytorch:: 100%|██████████| 7298/7298 [00:01<00:00, 6942.80it/s]

# %%
import os

# List the dataset directory structure
dataset_path = '/content/hairnet-15'
for root, dirs, files in os.walk(dataset_path):
    print(f"Directory: {root}")
    for file in files:
        print(f"  File: {file}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   File: Frame_12_802_100_jpg.rf.123b7d2fe85524b04d95c2d1bd0b3e0f.jpg
#   File: Frame_302_29_jpg.rf.f958aa4084889941eab3471b49564ae4.jpg
#   File: hairr_mp4-95_jpg.rf.3093840169346c9875695d2ee579f0b6.jpg
#   File: hairnet_ver_8_mp4-235_jpg.rf.23f4e97230b3e17c612e91b95dc4ab88.jpg
#   File: Frame_802_15_jpg.rf.10bf55e2de05b970b47597ee35350942.jpg
#   File: hair1_mp4-69_jpg.rf.1f27ba78c597bc51f483fc4f6c828a7b.jpg
#   File: 378_png_jpg.rf.c2968bf09cb0613bf596267ffd36a314.jpg
#   File: 16_png_jpg.rf.9cedd1015ec9cd088b1596b5b1ccd519.jpg
#   File: video_BC4_image_483_png_jpg.rf.06c45c3afc029b85cca6c899dbc5e261.jpg
#   File: hairnet_ver_8_mp4-185_jpg.rf.3bee12ad33b09969c42a44d68fdb9b2a.jpg
#   File: hair05_mp4-51_jpg.rf.b60a194c7266294301fb5edd18013cba.jpg
#   File: hairnet_102_mp4-43_jpg.rf.0f939d503ee5f599d02ba604dc69b725.jpg
#   File: Frame_302_49_jpg.rf.bf5270193bf206fbf4f287b3c02f189a.jpg
# ...

# %%
import os

dataset_path = '/content/hairnet-15'

for subset in ['train', 'test', 'valid']:
    images_path = os.path.join(dataset_path, subset, 'images')
    labels_path = os.path.join(dataset_path, subset, 'labels')

    print(f"{subset.upper()} SET:")
    print(f"  Number of images: {len(os.listdir(images_path))}")
    print(f"  Number of labels: {len(os.listdir(labels_path))}")
    print("-" * 30)
# Out:
# TRAIN SET:
#   Number of images: 2658
#   Number of labels: 2658
# ------------------------------
# TEST SET:
#   Number of images: 387
#   Number of labels: 387
# ------------------------------
# VALID SET:
#   Number of images: 598
#   Number of labels: 598
# ------------------------------

# %%
from ultralytics import YOLO

# Load your pretrained model
model = YOLO('/content/bestest.pt')

# %%
print("Classes the model can detect:", model.names)
# Out:
# Classes the model can detect: {0: 'Excavator', 1: 'Gloves', 2: 'Hardhat', 3: 'Ladder', 4: 'Mask', 5: 'NO-Hardhat', 6: 'NO-Mask', 7: 'NO-Safety Vest', 8: 'Person', 9: 'SUV', 10: 'Safety Cone', 11: 'Safety Vest', 12: 'bus', 13: 'dump truck', 14: 'fire hydrant', 15: 'machinery', 16: 'mini-van', 17: 'sedan', 18: 'semi', 19: 'trailer', 20: 'truck and trailer', 21: 'truck', 22: 'van', 23: 'vehicle', 24: 'wheel loader'}

# %%
# Train the model on the new dataset
model.train(
    data='/content/hairnet-15/data.yaml',  # Path to your data.yaml
    epochs=10,                             # Train for 10 epochs
    imgsz=640,                             # Image size
    batch=16,                              # Batch size
    workers=2,                             # Number of workers
    save_period=1,                         # Save model after every epoch
    name='finetuned_model_hairnet'                   # Model name for this run
)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load the newly trained model
model = YOLO('/content/runs/detect/finetuned_model_hairnet/weights/best.pt')

# Run evaluation on the validation dataset
results = model.val(data='/content/hairnet-15/data.yaml')  # Path to the updated data.yaml

# View the evaluation results
print(results)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,010,913 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/hairnet-15/valid/labels.cache... 598 images, 4 backgrounds, 0 corrupt: 100%|██████████| 598/598 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 38/38 [00:05<00:00,  6.68it/s]
#                    all        598       1332      0.954      0.954      0.978      0.597
#              Excavator        321        629      0.941      0.933      0.971      0.599
#                 Gloves        347        703      0.968      0.974      0.985      0.596
# Speed: 0.2ms preprocess, 2.8ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
rf = Roboflow(api_key="VN28ceooZnimGyMKzkNo")
project = rf.workspace("balldog").project("masker-llh3j-dz4qo-kdpeg")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Masker-1 in yolov5pytorch:: 100%|██████████| 1212/1212 [00:00<00:00, 8339.89it/s]

# %%
import os

dataset_path = '/content/Masker-1'

for subset in ['train', 'test', 'valid']:
    images_path = os.path.join(dataset_path, subset, 'images')
    labels_path = os.path.join(dataset_path, subset, 'labels')

    print(f"{subset.upper()} SET:")
    print(f"  Number of images: {len(os.listdir(images_path))}")
    print(f"  Number of labels: {len(os.listdir(labels_path))}")
    print("-" * 30)
# Out:
# TRAIN SET:
#   Number of images: 500
#   Number of labels: 500
# ------------------------------
# TEST SET:
#   Number of images: 30
#   Number of labels: 30
# ------------------------------
# VALID SET:
#   Number of images: 70
#   Number of labels: 70
# ------------------------------

# %%
model2 = YOLO('/content/runs/detect/finetuned_model_hairnet/weights/best.pt')
print("Classes the model can detect:", model2.names)
# Out:
# Classes the model can detect: {0: 'Excavator', 1: 'Gloves', 2: 'Hardhat', 3: 'Ladder', 4: 'Mask', 5: 'NO-Hardhat', 6: 'NO-Mask', 7: 'NO-Safety Vest', 8: 'Person', 9: 'SUV', 10: 'Safety Cone', 11: 'Safety Vest', 12: 'bus', 13: 'dump truck', 14: 'fire hydrant', 15: 'machinery', 16: 'mini-van', 17: 'sedan', 18: 'semi', 19: 'trailer', 20: 'truck and trailer', 21: 'truck', 22: 'van', 23: 'vehicle', 24: 'wheel loader', 25: 'hairnet', 26: 'no_hairnet'}

# %%
model2 = YOLO('/content/runs/detect/finetuned_model_hairnet/weights/best.pt')

# Train the model on the new dataset
model2.train(
    data='/content/Masker-1/data.yaml',  # Path to your data.yaml
    epochs=25,                             # Train for 10 epochs
    imgsz=640,                             # Image size
    batch=16,                              # Batch size
    workers=2,                             # Number of workers
    save_period=1,                         # Save model after every epoch
    name='finetuned_model_mask'                   # Model name for this run
)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load the newly trained model
model2 = YOLO('/content/runs/detect/finetuned_model_mask2/weights/best.pt')

# Run evaluation on the validation dataset
results = model2.val(data='/content/Masker-1/data.yaml')  # Path to the updated data.yaml

# View the evaluation results
print(results)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,011,498 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Masker-1/valid/labels.cache... 70 images, 32 backgrounds, 0 corrupt: 100%|██████████| 70/70 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:03<00:00,  1.54it/s]
#                    all         70         57      0.644      0.886      0.879      0.585
#              Excavator         14         17      0.778      0.765      0.918      0.595
#                 Gloves         31         37      0.859      0.892      0.931      0.679
#                Hardhat          3          3      0.295          1      0.789      0.482
# Speed: 0.6ms preprocess, 18.3ms inference, 0.0ms loss, 5.7ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...

# %%
model2.train(
    data='/content/Masker-1/data.yaml',  # Path to your updated data.yaml
    epochs=50,                           # Number of epochs for better convergence
    imgsz=640,                           # Image size
    batch=16,                            # Batch size
    workers=2,                           # Number of workers
    save_period=1,                       # Save model after every epoch
    name='finetuned_model_mask_v2',       # Name for the new model run
    lr0=0.001                            # Starting learning rate
)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load the newly trained model
model2 = YOLO('/content/runs/detect/finetuned_model_mask_v2/weights/best.pt')

# Run evaluation on the validation dataset
results = model2.val(data='/content/Masker-1/data.yaml')  # Path to the updated data.yaml

# View the evaluation results
print(results)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,011,498 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/Masker-1/valid/labels.cache... 70 images, 32 backgrounds, 0 corrupt: 100%|██████████| 70/70 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:02<00:00,  2.09it/s]
#                    all         70         57      0.867      0.791      0.906      0.598
#              Excavator         14         17      0.908       0.58       0.84      0.496
#                 Gloves         31         37      0.936      0.792      0.884      0.632
#                Hardhat          3          3      0.758          1      0.995      0.665
# Speed: 0.3ms preprocess, 6.0ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to runs/detect/val4
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ...
